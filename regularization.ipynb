# %%
## regularization adressiong overfit generalize underfit (high bias) 
## increasing datas , selecting features , decresing features coeff

# %%
## cost function with regularization: [1/(2*m) * sumof(error**2)] +[1/(2*m)] * lambda * sumof(w^j**2)  // error = y_pre-y  , wj sütun sütun w değerlerinin karesi

# %%
## regularized-linear-regression :
## dw  will change as 1/m * sumof(error*xİ^j) + lambda/m * w^jj  // j sütun sütun i satır satır ilerler ya da wj = wj(1-alpha*lambda/m) - alpha*dw  dw = 1/m * sumof(error*xİ^j)
## db de bir change yok 1/m * sumof(error)

# %%
##egularized-logistic-regression :
##  cost function for logistic regression: 1/m * sumof(loss) + lambda/ (2*m) * sumof(wj **2) // j sütun sütun
